# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs =  np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
from citipy import citipy
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 766

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key
print(weather_api_key)
# Out:
# e9b71909c622a1d4cabf350397330a8e

# %%
# Assemble the OpenWeatherMap's API call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e9b71909c622a1d4cabf350397330a8e

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descr = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat":city_lat,
                          "Lng":city_lng,
                          "Max_Temp": city_max_temp,
                           "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                           "Wind_Speed":city_wind,
                           "Country":city_country,
                           "Current_Description":city_weather_descr})
    # If an error is experienced, skip the city
    except Exception as e :
        print("City not found. Skipping...")
        print(e)
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | selikhino
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | cascais
# Processing Record 7 of Set 1 | botevgrad
# Processing Record 8 of Set 1 | valparaiso
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | erseke
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | ostrovnoy
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | maridi
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | iqaluit
# Processing Record 21 of Set 1 | necochea
# Processing Record 22 of Set 1 | hwange
# Processing Record 23 of Set 1 | beringovskiy
# Processing Record 24 of Set 1 | praia da vitoria
# Processing Record 25 of Set 1 | yago
# Processing Record 26 of Set 1 | coihaique
# Processing Record 27 of Set 1 | butterworth
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | kholtoson
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | laguna
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | araguacu
# Processing Record 38 of Set 1 | henin-beaumont
# Processing Record 39 of Set 1 | newport
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | cockburn town
# Processing Record 44 of Set 1 | altay
# Processing Record 45 of Set 1 | kismayo
# Processing Record 46 of Set 1 | roma
# Processing Record 47 of Set 1 | alindao
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | kavieng
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | saint-augustin
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# 'coord'
# Processing Record 6 of Set 2 | sabha
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# 'coord'
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 2 | hami
# Processing Record 11 of Set 2 | velsk
# Processing Record 12 of Set 2 | victoria
# Processing Record 13 of Set 2 | meyungs
# City not found. Skipping...
# 'coord'
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | najran
# Processing Record 16 of Set 2 | ndiekro
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 2 | gboko
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | srednekolymsk
# Processing Record 20 of Set 2 | lae
# Processing Record 21 of Set 2 | saleaula
# City not found. Skipping...
# 'coord'
# Processing Record 22 of Set 2 | yinchuan
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | pietersburg
# Processing Record 25 of Set 2 | urumqi
# Processing Record 26 of Set 2 | barranca
# Processing Record 27 of Set 2 | anadyr
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | biltine
# Processing Record 30 of Set 2 | tual
# Processing Record 31 of Set 2 | virginia beach
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | santa marta
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# 'coord'
# Processing Record 35 of Set 2 | minab
# Processing Record 36 of Set 2 | sept-iles
# Processing Record 37 of Set 2 | sitka
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# 'coord'
# Processing Record 40 of Set 2 | maragogi
# Processing Record 41 of Set 2 | santa cruz
# Processing Record 42 of Set 2 | padang
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | znamenskoye
# Processing Record 45 of Set 2 | inhambane
# Processing Record 46 of Set 2 | barawe
# City not found. Skipping...
# 'coord'
# Processing Record 47 of Set 2 | hasaki
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | basco
# Processing Record 1 of Set 3 | kodinsk
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | tabas
# Processing Record 4 of Set 3 | olinda
# Processing Record 5 of Set 3 | hobart
# Processing Record 6 of Set 3 | kruisfontein
# Processing Record 7 of Set 3 | maldonado
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | port lincoln
# Processing Record 10 of Set 3 | sorvag
# City not found. Skipping...
# 'coord'
# Processing Record 11 of Set 3 | attawapiskat
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 3 | saint-joseph
# Processing Record 13 of Set 3 | shimoda
# Processing Record 14 of Set 3 | luderitz
# Processing Record 15 of Set 3 | antipino
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | acapulco
# Processing Record 18 of Set 3 | caxito
# Processing Record 19 of Set 3 | mahebourg
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | byron bay
# Processing Record 22 of Set 3 | waipawa
# Processing Record 23 of Set 3 | ribeira grande
# Processing Record 24 of Set 3 | isangel
# Processing Record 25 of Set 3 | ozieri
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 3 | laibin
# Processing Record 28 of Set 3 | kolosovka
# Processing Record 29 of Set 3 | yunjinghong
# City not found. Skipping...
# 'coord'
# Processing Record 30 of Set 3 | chokurdakh
# Processing Record 31 of Set 3 | shetpe
# Processing Record 32 of Set 3 | hamilton
# Processing Record 33 of Set 3 | quesnel
# Processing Record 34 of Set 3 | ilulissat
# Processing Record 35 of Set 3 | salalah
# Processing Record 36 of Set 3 | constitucion
# Processing Record 37 of Set 3 | dunedin
# Processing Record 38 of Set 3 | nanortalik
# Processing Record 39 of Set 3 | nome
# Processing Record 40 of Set 3 | kargalinskaya
# Processing Record 41 of Set 3 | saldanha
# Processing Record 42 of Set 3 | myatlevo
# Processing Record 43 of Set 3 | port-gentil
# Processing Record 44 of Set 3 | bonthe
# Processing Record 45 of Set 3 | moose factory
# Processing Record 46 of Set 3 | avera
# Processing Record 47 of Set 3 | vaitupu
# City not found. Skipping...
# 'coord'
# Processing Record 48 of Set 3 | margate
# Processing Record 49 of Set 3 | morwell
# Processing Record 50 of Set 3 | chapleau
# Processing Record 1 of Set 4 | bela
# Processing Record 2 of Set 4 | mys shmidta
# City not found. Skipping...
# 'coord'
# Processing Record 3 of Set 4 | chifeng
# Processing Record 4 of Set 4 | lata
# Processing Record 5 of Set 4 | hay river
# Processing Record 6 of Set 4 | cherskiy
# Processing Record 7 of Set 4 | jiexiu
# Processing Record 8 of Set 4 | chuy
# Processing Record 9 of Set 4 | pocone
# Processing Record 10 of Set 4 | kochubey
# Processing Record 11 of Set 4 | alofi
# Processing Record 12 of Set 4 | half moon bay
# Processing Record 13 of Set 4 | madaoua
# Processing Record 14 of Set 4 | serra talhada
# Processing Record 15 of Set 4 | tautira
# Processing Record 16 of Set 4 | ayacucho
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | aklavik
# Processing Record 19 of Set 4 | bredasdorp
# Processing Record 20 of Set 4 | tiksi
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | rocha
# Processing Record 23 of Set 4 | nizhneyansk
# City not found. Skipping...
# 'coord'
# Processing Record 24 of Set 4 | butembo
# Processing Record 25 of Set 4 | atasu
# Processing Record 26 of Set 4 | varena
# Processing Record 27 of Set 4 | hualmay
# Processing Record 28 of Set 4 | ambodifototra
# City not found. Skipping...
# 'coord'
# Processing Record 29 of Set 4 | airai
# Processing Record 30 of Set 4 | qingdao
# Processing Record 31 of Set 4 | port alfred
# Processing Record 32 of Set 4 | san rafael del sur
# Processing Record 33 of Set 4 | kadykchan
# City not found. Skipping...
# 'coord'
# Processing Record 34 of Set 4 | brigantine
# Processing Record 35 of Set 4 | taoudenni
# Processing Record 36 of Set 4 | juneau
# Processing Record 37 of Set 4 | plettenberg bay
# Processing Record 38 of Set 4 | phuket
# Processing Record 39 of Set 4 | novaya igirma
# Processing Record 40 of Set 4 | nara
# Processing Record 41 of Set 4 | shumskiy
# Processing Record 42 of Set 4 | saskylakh
# Processing Record 43 of Set 4 | phan rang
# City not found. Skipping...
# 'coord'
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# 'coord'
# Processing Record 46 of Set 4 | edgewater
# Processing Record 47 of Set 4 | mitsamiouli
# Processing Record 48 of Set 4 | namatanai
# Processing Record 49 of Set 4 | baruun-urt
# Processing Record 50 of Set 4 | thaba-tseka
# Processing Record 1 of Set 5 | puri
# Processing Record 2 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 5 | stoyba
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 5 | goure
# Processing Record 5 of Set 5 | kaitangata
# Processing Record 6 of Set 5 | sorland
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | zhigansk
# Processing Record 9 of Set 5 | katsuura
# Processing Record 10 of Set 5 | mahanje
# Processing Record 11 of Set 5 | tasiilaq
# Processing Record 12 of Set 5 | tabiauea
# City not found. Skipping...
# 'coord'
# Processing Record 13 of Set 5 | ballina
# Processing Record 14 of Set 5 | fortuna
# Processing Record 15 of Set 5 | huarmey
# Processing Record 16 of Set 5 | batagay
# Processing Record 17 of Set 5 | kahului
# Processing Record 18 of Set 5 | bakchar
# Processing Record 19 of Set 5 | poum
# Processing Record 20 of Set 5 | zhezkazgan
# Processing Record 21 of Set 5 | pilar
# Processing Record 22 of Set 5 | panaba
# Processing Record 23 of Set 5 | bahia blanca
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | kelowna
# Processing Record 26 of Set 5 | grand river south east
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 5 | vidim
# Processing Record 28 of Set 5 | itarema
# Processing Record 29 of Set 5 | bengkulu
# Processing Record 30 of Set 5 | dianopolis
# City not found. Skipping...
# 'coord'
# Processing Record 31 of Set 5 | madridejos
# Processing Record 32 of Set 5 | la libertad
# Processing Record 33 of Set 5 | biloela
# Processing Record 34 of Set 5 | nanlong
# Processing Record 35 of Set 5 | vardo
# Processing Record 36 of Set 5 | gayny
# Processing Record 37 of Set 5 | chute-aux-outardes
# Processing Record 38 of Set 5 | gazli
# Processing Record 39 of Set 5 | satitoa
# City not found. Skipping...
# 'coord'
# Processing Record 40 of Set 5 | itoman
# Processing Record 41 of Set 5 | tupi paulista
# Processing Record 42 of Set 5 | tara
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | aflu
# City not found. Skipping...
# 'coord'
# Processing Record 45 of Set 5 | kupang
# Processing Record 46 of Set 5 | okha
# Processing Record 47 of Set 5 | rawatbhata
# Processing Record 48 of Set 5 | chapada dos guimaraes
# Processing Record 49 of Set 5 | hithadhoo
# Processing Record 50 of Set 5 | south river
# Processing Record 1 of Set 6 | sokolskoye
# Processing Record 2 of Set 6 | katobu
# Processing Record 3 of Set 6 | kissidougou
# Processing Record 4 of Set 6 | comodoro rivadavia
# Processing Record 5 of Set 6 | cayenne
# Processing Record 6 of Set 6 | lethbridge
# Processing Record 7 of Set 6 | ukiah
# Processing Record 8 of Set 6 | impfondo
# Processing Record 9 of Set 6 | panguna
# Processing Record 10 of Set 6 | vestmanna
# Processing Record 11 of Set 6 | bonavista
# Processing Record 12 of Set 6 | nhulunbuy
# Processing Record 13 of Set 6 | kalaleh
# Processing Record 14 of Set 6 | toulepleu
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 6 | corcoran
# Processing Record 16 of Set 6 | vao
# Processing Record 17 of Set 6 | kalmar
# Processing Record 18 of Set 6 | leningradskiy
# Processing Record 19 of Set 6 | omsukchan
# Processing Record 20 of Set 6 | aykhal
# Processing Record 21 of Set 6 | barcelona
# Processing Record 22 of Set 6 | morrisburg
# Processing Record 23 of Set 6 | victor harbor
# Processing Record 24 of Set 6 | vila franca do campo
# Processing Record 25 of Set 6 | upernavik
# Processing Record 26 of Set 6 | hofn
# Processing Record 27 of Set 6 | saint george
# Processing Record 28 of Set 6 | sosnovo-ozerskoye
# Processing Record 29 of Set 6 | santa engracia
# Processing Record 30 of Set 6 | camacha
# Processing Record 31 of Set 6 | yar-sale
# Processing Record 32 of Set 6 | kalmunai
# Processing Record 33 of Set 6 | clyde river
# Processing Record 34 of Set 6 | borujerd
# Processing Record 35 of Set 6 | armacao dos buzios
# City not found. Skipping...
# 'coord'
# Processing Record 36 of Set 6 | berlevag
# Processing Record 37 of Set 6 | carbonear
# Processing Record 38 of Set 6 | mola di bari
# Processing Record 39 of Set 6 | baykit
# Processing Record 40 of Set 6 | aswan
# Processing Record 41 of Set 6 | sale
# Processing Record 42 of Set 6 | moussoro
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | bathurst
# Processing Record 45 of Set 6 | lloydminster
# Processing Record 46 of Set 6 | bathsheba
# Processing Record 47 of Set 6 | palmer
# Processing Record 48 of Set 6 | yaransk
# Processing Record 49 of Set 6 | samusu
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 6 | tumannyy
# City not found. Skipping...
# 'coord'
# Processing Record 1 of Set 7 | caravelas
# Processing Record 2 of Set 7 | sikonge
# Processing Record 3 of Set 7 | san cristobal
# Processing Record 4 of Set 7 | karauzyak
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 7 | new port richey
# Processing Record 6 of Set 7 | progreso
# Processing Record 7 of Set 7 | leczna
# Processing Record 8 of Set 7 | tilichiki
# Processing Record 9 of Set 7 | high level
# Processing Record 10 of Set 7 | gizo
# Processing Record 11 of Set 7 | barahona
# Processing Record 12 of Set 7 | lasa
# Processing Record 13 of Set 7 | pangnirtung
# Processing Record 14 of Set 7 | skage
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 7 | kirakira
# Processing Record 16 of Set 7 | trairi
# Processing Record 17 of Set 7 | mabaruma
# Processing Record 18 of Set 7 | kalomo
# City not found. Skipping...
# 'coord'
# Processing Record 19 of Set 7 | talara
# Processing Record 20 of Set 7 | realeza
# Processing Record 21 of Set 7 | hambantota
# Processing Record 22 of Set 7 | chulman
# Processing Record 23 of Set 7 | vestmannaeyjar
# Processing Record 24 of Set 7 | almeirim
# Processing Record 25 of Set 7 | el alto
# Processing Record 26 of Set 7 | kirovskiy
# Processing Record 27 of Set 7 | linxia
# Processing Record 28 of Set 7 | soure
# Processing Record 29 of Set 7 | beirut
# Processing Record 30 of Set 7 | mogadishu
# Processing Record 31 of Set 7 | lagoa
# Processing Record 32 of Set 7 | auki
# Processing Record 33 of Set 7 | chapadinha
# Processing Record 34 of Set 7 | aksarka
# Processing Record 35 of Set 7 | kamaishi
# Processing Record 36 of Set 7 | oreanda
# City not found. Skipping...
# 'coord'
# Processing Record 37 of Set 7 | samarai
# Processing Record 38 of Set 7 | lorengau
# Processing Record 39 of Set 7 | lubango
# Processing Record 40 of Set 7 | paamiut
# Processing Record 41 of Set 7 | geraldton
# Processing Record 42 of Set 7 | semey
# Processing Record 43 of Set 7 | corinto
# Processing Record 44 of Set 7 | zaria
# Processing Record 45 of Set 7 | alekseyevsk
# Processing Record 46 of Set 7 | coahuayana
# Processing Record 47 of Set 7 | melfort
# Processing Record 48 of Set 7 | fomboni
# Processing Record 49 of Set 7 | okandja
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 7 | cermik
# Processing Record 1 of Set 8 | esperance
# Processing Record 2 of Set 8 | tres arroyos
# Processing Record 3 of Set 8 | boende
# Processing Record 4 of Set 8 | mancio lima
# Processing Record 5 of Set 8 | taltal
# Processing Record 6 of Set 8 | marcona
# City not found. Skipping...
# 'coord'
# Processing Record 7 of Set 8 | praia
# Processing Record 8 of Set 8 | cerro cama
# Processing Record 9 of Set 8 | ler
# Processing Record 10 of Set 8 | ulladulla
# Processing Record 11 of Set 8 | payo
# Processing Record 12 of Set 8 | kiruna
# Processing Record 13 of Set 8 | portland
# Processing Record 14 of Set 8 | tuatapere
# Processing Record 15 of Set 8 | taunggyi
# Processing Record 16 of Set 8 | ngukurr
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 8 | perth
# Processing Record 18 of Set 8 | ruatoria
# City not found. Skipping...
# 'coord'
# Processing Record 19 of Set 8 | whitehorse
# Processing Record 20 of Set 8 | seydi
# Processing Record 21 of Set 8 | san jose
# Processing Record 22 of Set 8 | scarborough
# Processing Record 23 of Set 8 | thanh hoa
# Processing Record 24 of Set 8 | villa bruzual
# Processing Record 25 of Set 8 | flinders
# Processing Record 26 of Set 8 | scottsbluff
# Processing Record 27 of Set 8 | sakakah
# Processing Record 28 of Set 8 | providencia
# Processing Record 29 of Set 8 | iskar
# Processing Record 30 of Set 8 | sao raimundo das mangabeiras
# Processing Record 31 of Set 8 | hirara
# Processing Record 32 of Set 8 | batagay-alyta
# Processing Record 33 of Set 8 | kajaani
# Processing Record 34 of Set 8 | general pico
# Processing Record 35 of Set 8 | ugra
# Processing Record 36 of Set 8 | kavaratti
# Processing Record 37 of Set 8 | mehamn
# Processing Record 38 of Set 8 | sorong
# Processing Record 39 of Set 8 | conde
# Processing Record 40 of Set 8 | vanimo
# Processing Record 41 of Set 8 | biak
# Processing Record 42 of Set 8 | lompoc
# Processing Record 43 of Set 8 | brae
# Processing Record 44 of Set 8 | tommot
# Processing Record 45 of Set 8 | vila do maio
# Processing Record 46 of Set 8 | mocambique
# City not found. Skipping...
# 'coord'
# Processing Record 47 of Set 8 | maningrida
# Processing Record 48 of Set 8 | husavik
# Processing Record 49 of Set 8 | kaabong
# Processing Record 50 of Set 8 | lodwar
# Processing Record 1 of Set 9 | ahipara
# Processing Record 2 of Set 9 | louisbourg
# City not found. Skipping...
# 'coord'
# Processing Record 3 of Set 9 | urfa
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 9 | sola
# Processing Record 5 of Set 9 | champerico
# Processing Record 6 of Set 9 | guilin
# Processing Record 7 of Set 9 | atagay
# Processing Record 8 of Set 9 | twentynine palms
# Processing Record 9 of Set 9 | ongandjera
# Processing Record 10 of Set 9 | nicoya
# Processing Record 11 of Set 9 | meulaboh
# Processing Record 12 of Set 9 | walvis bay
# Processing Record 13 of Set 9 | deputatskiy
# Processing Record 14 of Set 9 | zaraza
# Processing Record 15 of Set 9 | gijon
# Processing Record 16 of Set 9 | yagodnoye
# Processing Record 17 of Set 9 | bull savanna
# Processing Record 18 of Set 9 | bay roberts
# Processing Record 19 of Set 9 | tigil
# Processing Record 20 of Set 9 | bethel
# Processing Record 21 of Set 9 | sao felix do xingu
# Processing Record 22 of Set 9 | porto novo
# Processing Record 23 of Set 9 | contamana
# Processing Record 24 of Set 9 | dumas
# Processing Record 25 of Set 9 | carlisle
# Processing Record 26 of Set 9 | ketchenery
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 9 | mergui
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 9 | mentok
# City not found. Skipping...
# 'coord'
# Processing Record 29 of Set 9 | mayo
# Processing Record 30 of Set 9 | mutsamudu
# City not found. Skipping...
# 'coord'
# Processing Record 31 of Set 9 | la romana
# Processing Record 32 of Set 9 | prieska
# Processing Record 33 of Set 9 | arman
# Processing Record 34 of Set 9 | luwuk
# Processing Record 35 of Set 9 | sao miguel do araguaia
# Processing Record 36 of Set 9 | beloha
# Processing Record 37 of Set 9 | labytnangi
# Processing Record 38 of Set 9 | codrington
# Processing Record 39 of Set 9 | buenaventura
# Processing Record 40 of Set 9 | arcelia
# Processing Record 41 of Set 9 | palabuhanratu
# City not found. Skipping...
# 'coord'
# Processing Record 42 of Set 9 | mezen
# Processing Record 43 of Set 9 | lalmohan
# Processing Record 44 of Set 9 | cootamundra
# Processing Record 45 of Set 9 | dragoesti
# Processing Record 46 of Set 9 | yambio
# Processing Record 47 of Set 9 | laiagam
# City not found. Skipping...
# 'coord'
# Processing Record 48 of Set 9 | santa
# Processing Record 49 of Set 9 | kolyvan
# Processing Record 50 of Set 9 | suining
# Processing Record 1 of Set 10 | nguiu
# City not found. Skipping...
# 'coord'
# Processing Record 2 of Set 10 | maua
# Processing Record 3 of Set 10 | mbanza-ngungu
# Processing Record 4 of Set 10 | muzhi
# Processing Record 5 of Set 10 | rawannawi
# City not found. Skipping...
# 'coord'
# Processing Record 6 of Set 10 | kasungu
# Processing Record 7 of Set 10 | boffa
# Processing Record 8 of Set 10 | desnogorsk
# Processing Record 9 of Set 10 | bibiani
# Processing Record 10 of Set 10 | buala
# Processing Record 11 of Set 10 | oum hadjer
# Processing Record 12 of Set 10 | palkaka
# City not found. Skipping...
# 'coord'
# Processing Record 13 of Set 10 | ilanskiy
# Processing Record 14 of Set 10 | faya
# Processing Record 15 of Set 10 | nizhneangarsk
# Processing Record 16 of Set 10 | mekhe
# Processing Record 17 of Set 10 | ouegoa
# Processing Record 18 of Set 10 | guelengdeng
# City not found. Skipping...
# 'coord'
# Processing Record 19 of Set 10 | buon me thuot
# City not found. Skipping...
# 'coord'
# Processing Record 20 of Set 10 | harper
# Processing Record 21 of Set 10 | lavrentiya
# Processing Record 22 of Set 10 | bo phloi
# Processing Record 23 of Set 10 | ternate
# Processing Record 24 of Set 10 | chaoyang
# Processing Record 25 of Set 10 | rio tinto
# Processing Record 26 of Set 10 | yenagoa
# Processing Record 27 of Set 10 | erie
# Processing Record 28 of Set 10 | mugango
# Processing Record 29 of Set 10 | north bend
# Processing Record 30 of Set 10 | kutum
# Processing Record 31 of Set 10 | derzhavinsk
# Processing Record 32 of Set 10 | puksoozero
# Processing Record 33 of Set 10 | felipe carrillo puerto
# Processing Record 34 of Set 10 | khatanga
# Processing Record 35 of Set 10 | monfalcone
# Processing Record 36 of Set 10 | dillon
# Processing Record 37 of Set 10 | komsomolskiy
# Processing Record 38 of Set 10 | bagdarin
# Processing Record 39 of Set 10 | ondarroa
# Processing Record 40 of Set 10 | yuci
# Processing Record 41 of Set 10 | merauke
# Processing Record 42 of Set 10 | la spezia
# Processing Record 43 of Set 10 | namibe
# Processing Record 44 of Set 10 | nabire
# Processing Record 45 of Set 10 | frekhaug
# Processing Record 46 of Set 10 | belmonte
# Processing Record 47 of Set 10 | ancud
# Processing Record 48 of Set 10 | valentin gomez farias
# Processing Record 49 of Set 10 | alta floresta
# Processing Record 50 of Set 10 | manacapuru
# Processing Record 1 of Set 11 | auriflama
# Processing Record 2 of Set 11 | sinnamary
# Processing Record 3 of Set 11 | daoukro
# Processing Record 4 of Set 11 | yeniseysk
# Processing Record 5 of Set 11 | riobamba
# Processing Record 6 of Set 11 | sao filipe
# Processing Record 7 of Set 11 | forquilhinha
# Processing Record 8 of Set 11 | umzimvubu
# City not found. Skipping...
# 'coord'
# Processing Record 9 of Set 11 | isla mujeres
# Processing Record 10 of Set 11 | coquimbo
# Processing Record 11 of Set 11 | punahana
# Processing Record 12 of Set 11 | pangody
# Processing Record 13 of Set 11 | verkhnevilyuysk
# Processing Record 14 of Set 11 | richards bay
# Processing Record 15 of Set 11 | chapais
# Processing Record 16 of Set 11 | kysyl-syr
# Processing Record 17 of Set 11 | mmabatho
# Processing Record 18 of Set 11 | charters towers
# Processing Record 19 of Set 11 | mount gambier
# Processing Record 20 of Set 11 | bindura
# Processing Record 21 of Set 11 | santa maria
# Processing Record 22 of Set 11 | marsh harbour
# Processing Record 23 of Set 11 | claveria
# Processing Record 24 of Set 11 | sao joao da barra
# Processing Record 25 of Set 11 | naryan-mar
# Processing Record 26 of Set 11 | baringo
# Processing Record 27 of Set 11 | porto velho
# Processing Record 28 of Set 11 | mount hagen
# Processing Record 29 of Set 11 | high point
# Processing Record 30 of Set 11 | narsaq
# Processing Record 31 of Set 11 | nuuk
# Processing Record 32 of Set 11 | rajapur
# Processing Record 33 of Set 11 | sisak
# Processing Record 34 of Set 11 | cabedelo
# Processing Record 35 of Set 11 | bandarbeyla
# Processing Record 36 of Set 11 | ambilobe
# Processing Record 37 of Set 11 | catemaco
# Processing Record 38 of Set 11 | puerto escondido
# Processing Record 39 of Set 11 | lagos
# Processing Record 40 of Set 11 | labis
# Processing Record 41 of Set 11 | pedernales
# Processing Record 42 of Set 11 | bunol
# Processing Record 43 of Set 11 | bin qirdan
# Processing Record 44 of Set 11 | teya
# Processing Record 45 of Set 11 | klaksvik
# Processing Record 46 of Set 11 | mozarlandia
# Processing Record 47 of Set 11 | halalo
# City not found. Skipping...
# 'coord'
# Processing Record 48 of Set 11 | buin
# Processing Record 49 of Set 11 | longlac
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 11 | west wendover
# Processing Record 1 of Set 12 | barra patuca
# Processing Record 2 of Set 12 | rivera
# Processing Record 3 of Set 12 | sault sainte marie
# Processing Record 4 of Set 12 | gimli
# Processing Record 5 of Set 12 | mahon
# Processing Record 6 of Set 12 | karaul
# City not found. Skipping...
# 'coord'
# Processing Record 7 of Set 12 | humberto de campos
# Processing Record 8 of Set 12 | todos santos
# Processing Record 9 of Set 12 | ito
# Processing Record 10 of Set 12 | cumaribo
# City not found. Skipping...
# 'coord'
# Processing Record 11 of Set 12 | cooma
# Processing Record 12 of Set 12 | yokote
# Processing Record 13 of Set 12 | andijon
# Processing Record 14 of Set 12 | carutapera
# Processing Record 15 of Set 12 | panama city
# Processing Record 16 of Set 12 | tiznit
# Processing Record 17 of Set 12 | astana
# Processing Record 18 of Set 12 | belance
# Processing Record 19 of Set 12 | surt
# Processing Record 20 of Set 12 | san juan
# Processing Record 21 of Set 12 | rybinsk
# Processing Record 22 of Set 12 | ambikapur
# Processing Record 23 of Set 12 | pasighat
# Processing Record 24 of Set 12 | skjervoy
# Processing Record 25 of Set 12 | duncan
# Processing Record 26 of Set 12 | sundsvall
# Processing Record 27 of Set 12 | casino
# Processing Record 28 of Set 12 | bam
# Processing Record 29 of Set 12 | san julian
# Processing Record 30 of Set 12 | henties bay
# Processing Record 31 of Set 12 | one hundred mile house
# City not found. Skipping...
# 'coord'
# Processing Record 32 of Set 12 | makokou
# Processing Record 33 of Set 12 | mongoumba
# Processing Record 34 of Set 12 | pandamatenga
# Processing Record 35 of Set 12 | camapua
# Processing Record 36 of Set 12 | safford
# Processing Record 37 of Set 12 | xining
# Processing Record 38 of Set 12 | harrisburg
# Processing Record 39 of Set 12 | canton
# Processing Record 40 of Set 12 | uruzgan
# Processing Record 41 of Set 12 | minot
# Processing Record 42 of Set 12 | dekar
# Processing Record 43 of Set 12 | shenjiamen
# Processing Record 44 of Set 12 | artyom
# Processing Record 45 of Set 12 | kolaras
# Processing Record 46 of Set 12 | broken hill
# Processing Record 47 of Set 12 | port hardy
# Processing Record 48 of Set 12 | guangyuan
# Processing Record 49 of Set 12 | peterhead
# Processing Record 50 of Set 12 | evensk
# Processing Record 1 of Set 13 | nemuro
# Processing Record 2 of Set 13 | markova
# Processing Record 3 of Set 13 | bekovo
# Processing Record 4 of Set 13 | vidra
# Processing Record 5 of Set 13 | mchinji
# Processing Record 6 of Set 13 | teguise
# Processing Record 7 of Set 13 | ljungby
# Processing Record 8 of Set 13 | aljezur
# Processing Record 9 of Set 13 | chagda
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 13 | ixtapa
# Processing Record 11 of Set 13 | yanan
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 13 | acarau
# Processing Record 13 of Set 13 | zyryanka
# Processing Record 14 of Set 13 | kazalinsk
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 13 | jodhpur
# Processing Record 16 of Set 13 | temaraia
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 13 | clifton
# Processing Record 18 of Set 13 | norsup
# Processing Record 19 of Set 13 | nouadhibou
# Processing Record 20 of Set 13 | mincivan
# Processing Record 21 of Set 13 | gualan
# Processing Record 22 of Set 13 | yumen
# Processing Record 23 of Set 13 | bend
# Processing Record 24 of Set 13 | kibala
# Processing Record 25 of Set 13 | montmagny
# Processing Record 26 of Set 13 | conakry
# Processing Record 27 of Set 13 | quatre cocos
# Processing Record 28 of Set 13 | mackay
# Processing Record 29 of Set 13 | lima
# Processing Record 30 of Set 13 | turukhansk
# Processing Record 31 of Set 13 | horodyshche
# Processing Record 32 of Set 13 | zaranj
# Processing Record 33 of Set 13 | luena
# Processing Record 34 of Set 13 | kuzhithurai
# Processing Record 35 of Set 13 | gigmoto
# Processing Record 36 of Set 13 | george
# Processing Record 37 of Set 13 | singkang
# Processing Record 38 of Set 13 | bambanglipuro
# Processing Record 39 of Set 13 | araouane
# Processing Record 40 of Set 13 | eureka
# Processing Record 41 of Set 13 | ponnani
# Processing Record 42 of Set 13 | tambura
# Processing Record 43 of Set 13 | salamiyah
# Processing Record 44 of Set 13 | vaitape
# Processing Record 45 of Set 13 | falmouth
# Processing Record 46 of Set 13 | kieta
# Processing Record 47 of Set 13 | jinchang
# Processing Record 48 of Set 13 | abalak
# Processing Record 49 of Set 13 | kangaatsiaq
# Processing Record 50 of Set 13 | pandan
# Processing Record 1 of Set 14 | ratnagiri
# Processing Record 2 of Set 14 | oriximina
# Processing Record 3 of Set 14 | ust-uda
# Processing Record 4 of Set 14 | riyadh
# Processing Record 5 of Set 14 | petropavlovka
# Processing Record 6 of Set 14 | iberia
# Processing Record 7 of Set 14 | troitskoye
# Processing Record 8 of Set 14 | zile
# Processing Record 9 of Set 14 | fairbanks
# Processing Record 10 of Set 14 | gobabis
# Processing Record 11 of Set 14 | xuddur
# Processing Record 12 of Set 14 | solnechnyy
# Processing Record 13 of Set 14 | garmsar
# Processing Record 14 of Set 14 | tevaitoa
# Processing Record 15 of Set 14 | crestview
# Processing Record 16 of Set 14 | guarapari
# Processing Record 17 of Set 14 | talnakh
# Processing Record 18 of Set 14 | morondava
# Processing Record 19 of Set 14 | bocas del toro
# Processing Record 20 of Set 14 | isla vista
# Processing Record 21 of Set 14 | lucera
# Processing Record 22 of Set 14 | sungaipenuh
# Processing Record 23 of Set 14 | norrtalje
# Processing Record 24 of Set 14 | hit
# Processing Record 25 of Set 14 | norman wells
# Processing Record 26 of Set 14 | yarmouth
# Processing Record 27 of Set 14 | ketchikan
# Processing Record 28 of Set 14 | lysyye gory
# Processing Record 29 of Set 14 | gondanglegi
# Processing Record 30 of Set 14 | porto de moz
# Processing Record 31 of Set 14 | makhachkala
# Processing Record 32 of Set 14 | kushmurun
# Processing Record 33 of Set 14 | vostok
# Processing Record 34 of Set 14 | maputo
# Processing Record 35 of Set 14 | amahai
# Processing Record 36 of Set 14 | tombouctou
# Processing Record 37 of Set 14 | bakel
# Processing Record 38 of Set 14 | kostek
# Processing Record 39 of Set 14 | owando
# Processing Record 40 of Set 14 | san luis
# Processing Record 41 of Set 14 | paracatu
# Processing Record 42 of Set 14 | erdenet
# Processing Record 43 of Set 14 | novo cruzeiro
# Processing Record 44 of Set 14 | berdigestyakh
# Processing Record 45 of Set 14 | sulangan
# Processing Record 46 of Set 14 | boa vista
# Processing Record 47 of Set 14 | mahanoro
# Processing Record 48 of Set 14 | catuday
# Processing Record 49 of Set 14 | jackson
# Processing Record 50 of Set 14 | chak jhumra
# Processing Record 1 of Set 15 | biryusinsk
# Processing Record 2 of Set 15 | moshi
# Processing Record 3 of Set 15 | alice springs
# Processing Record 4 of Set 15 | olafsvik
# Processing Record 5 of Set 15 | la ronge
# Processing Record 6 of Set 15 | prudentopolis
# Processing Record 7 of Set 15 | ulagan
# Processing Record 8 of Set 15 | ayan
# Processing Record 9 of Set 15 | serra branca
# Processing Record 10 of Set 15 | masunga
# Processing Record 11 of Set 15 | saryshagan
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 15 | san policarpo
# Processing Record 13 of Set 15 | tagusao
# Processing Record 14 of Set 15 | urubicha
# Processing Record 15 of Set 15 | biskamzha
# Processing Record 16 of Set 15 | paradwip
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 15 | collipulli
# Processing Record 18 of Set 15 | asau
# Processing Record 19 of Set 15 | jeremie
# Processing Record 20 of Set 15 | san ramon
# Processing Record 21 of Set 15 | chumikan
# Processing Record 22 of Set 15 | neyshabur
# Processing Record 23 of Set 15 | college
# Processing Record 24 of Set 15 | hobyo
# Processing Record 25 of Set 15 | chekalin
# Processing Record 26 of Set 15 | innisfail
# Processing Record 27 of Set 15 | mon
# Processing Record 28 of Set 15 | myaundzha
# Processing Record 29 of Set 15 | ascension
# Processing Record 30 of Set 15 | yuli
# Processing Record 31 of Set 15 | presidencia roque saenz pena
# Processing Record 32 of Set 15 | krasnoselkup
# Processing Record 33 of Set 15 | cozumel
# Processing Record 34 of Set 15 | griffith
# Processing Record 35 of Set 15 | hearst
# Processing Record 36 of Set 15 | el negrito
# Processing Record 37 of Set 15 | garissa
# Processing Record 38 of Set 15 | svetlogorsk
# Processing Record 39 of Set 15 | magadan
# Processing Record 40 of Set 15 | bolshiye chapurniki
# City not found. Skipping...
# 'coord'
# Processing Record 41 of Set 15 | meiganga
# Processing Record 42 of Set 15 | venado tuerto
# Processing Record 43 of Set 15 | grand gaube
# Processing Record 44 of Set 15 | karamay
# City not found. Skipping...
# 'coord'
# Processing Record 45 of Set 15 | tecoanapa
# Processing Record 46 of Set 15 | ashland
# Processing Record 47 of Set 15 | kandrian
# Processing Record 48 of Set 15 | hovd
# Processing Record 49 of Set 15 | kifri
# Processing Record 50 of Set 15 | batemans bay
# Processing Record 1 of Set 16 | okulovka
# Processing Record 2 of Set 16 | mantua
# Processing Record 3 of Set 16 | tura
# Processing Record 4 of Set 16 | honningsvag
# Processing Record 5 of Set 16 | freeport
# Processing Record 6 of Set 16 | yining
# Processing Record 7 of Set 16 | port victoria
# Processing Record 8 of Set 16 | denpasar
# Processing Record 9 of Set 16 | tolga
# Processing Record 10 of Set 16 | lakatoro
# Processing Record 11 of Set 16 | izacic
# Processing Record 12 of Set 16 | kurilsk
# Processing Record 13 of Set 16 | nagutskoye
# Processing Record 14 of Set 16 | opobo
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 16 | aban
# Processing Record 16 of Set 16 | tezu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
print(city_data)
# Out:
# [{'City': 'Mataura', 'Lat': -46.1927, 'Lng': 168.8643, 'Max_Temp': 59.41, 'Humidity': 52, 'Cloudiness': 33, 'Wind_Speed': 5.19, 'Country': 'NZ', 'Current_Description': 'scattered clouds'}, {'City': 'Vaini', 'Lat': -21.2, 'Lng': -175.2, 'Max_Temp': 75.36, 'Humidity': 94, 'Cloudiness': 100, 'Wind_Speed': 9.22, 'Country': 'TO', 'Current_Description': 'moderate rain'}, {'City': 'Selikhino', 'Lat': 50.3672, 'Lng': 137.4996, 'Max_Temp': 2.43, 'Humidity': 91, 'Cloudiness': 100, 'Wind_Speed': 12.91, 'Country': 'RU', 'Current_Description': 'overcast clouds'}, {'City': 'Punta Arenas', 'Lat': -53.15, 'Lng': -70.9167, 'Max_Temp': 46.51, 'Humidity': 71, 'Cloudiness': 75, 'Wind_Speed': 9.22, 'Country': 'CL', 'Current_Description': 'light rain'}, {'City': 'Arraial Do Cabo', 'Lat': -22.9661, 'Lng': -42.0278, 'Max_Temp': 72.3, 'Humidity': 93, 'Cloudiness': 100, 'Wind_Speed': 2.28, 'Country': 'BR', 'Current_Description': 'overcast clouds'}, {'City': 'Cascais', 'Lat': 38.6979, 'Lng': -9.4215, 'Max_Temp': 62.51, 'Humidity': 95, 'Cloudiness': 100, 'Wind_Speed': 11.99, 'Country': 'PT', 'Current_Description': 'overcast clouds'}, {'City': 'Botevgrad', 'Lat': 42.9, 'Lng': 23.7833, 'Max_Temp': 40.53, 'Humidity': 83, 'Cloudiness': 12, 'Wind_Speed': 5.12, 'Country': 'BG', 'Current_Description': 'few clouds'}, {'City': 'Valparaiso', 'Lat': -33.0393, 'Lng': -71.6273, 'Max_Temp': 60.44, 'Humidity': 88, 'Cloudiness': 100, 'Wind_Speed': 9.22, 'Country': 'CL', 'Current_Description': 'overcast clouds'}, {'City': 'Lebu', 'Lat': -37.6167, 'Lng': -73.65, 'Max_Temp': 56.46, 'Humidity': 92, 'Cloudiness': 22, 'Wind_Speed': 20.29, 'Country': 'CL', 'Current_Description': 'few clouds'}, {'City': 'Erseke', 'Lat': 40.3378, 'Lng': 20.6789, 'Max_Temp': 38.34, 'Humidity': 92, 'Cloudiness': 89, 'Wind_Speed': 1.59, 'Country': 'AL', 'Current_Description': 'overcast clouds'}, {'City': 'Puerto Ayora', 'Lat': -0.7393, 'Lng': -90.3518, 'Max_Temp': 71.55, 'Humidity': 96, 'Cloudiness': 51, 'Wind_Speed': 4.59, 'Country': 'EC', 'Current_Description': 'broken clouds'}, {'City': 'Busselton', 'Lat': -33.65, 'Lng': 115.3333, 'Max_Temp': 83.32, 'Humidity': 41, 'Cloudiness': 0, 'Wind_Speed': 15.48, 'Country': 'AU', 'Current_Description': 'clear sky'}, {'City': 'Castro', 'Lat': -24.7911, 'Lng': -50.0119, 'Max_Temp': 60.13, 'Humidity': 95, 'Cloudiness': 96, 'Wind_Speed': 7.63, 'Country': 'BR', 'Current_Description': 'overcast clouds'}, {'City': 'Ostrovnoy', 'Lat': 68.0531, 'Lng': 39.5131, 'Max_Temp': 16, 'Humidity': 90, 'Cloudiness': 26, 'Wind_Speed': 15.39, 'Country': 'RU', 'Current_Description': 'scattered clouds'}, {'City': 'Port Elizabeth', 'Lat': -33.918, 'Lng': 25.5701, 'Max_Temp': 70.32, 'Humidity': 59, 'Cloudiness': 29, 'Wind_Speed': 4, 'Country': 'ZA', 'Current_Description': 'scattered clouds'}, {'City': 'Ushuaia', 'Lat': -54.8, 'Lng': -68.3, 'Max_Temp': 44.26, 'Humidity': 76, 'Cloudiness': 100, 'Wind_Speed': 19.57, 'Country': 'AR', 'Current_Description': 'light rain'}, {'City': 'Mar Del Plata', 'Lat': -38.0023, 'Lng': -57.5575, 'Max_Temp': 66.09, 'Humidity': 69, 'Cloudiness': 99, 'Wind_Speed': 8.01, 'Country': 'AR', 'Current_Description': 'overcast clouds'}, {'City': 'Maridi', 'Lat': 4.9158, 'Lng': 29.4742, 'Max_Temp': 81.61, 'Humidity': 28, 'Cloudiness': 11, 'Wind_Speed': 7.49, 'Country': 'SS', 'Current_Description': 'few clouds'}, {'City': 'Ponta Do Sol', 'Lat': 32.6667, 'Lng': -17.1, 'Max_Temp': 67.12, 'Humidity': 28, 'Cloudiness': 83, 'Wind_Speed': 6.15, 'Country': 'PT', 'Current_Description': 'broken clouds'}, {'City': 'Iqaluit', 'Lat': 63.7506, 'Lng': -68.5145, 'Max_Temp': -21.51, 'Humidity': 89, 'Cloudiness': 6, 'Wind_Speed': 13.82, 'Country': 'CA', 'Current_Description': 'clear sky'}, {'City': 'Necochea', 'Lat': -38.5473, 'Lng': -58.7368, 'Max_Temp': 62.11, 'Humidity': 53, 'Cloudiness': 100, 'Wind_Speed': 8.1, 'Country': 'AR', 'Current_Description': 'overcast clouds'}, {'City': 'Hwange', 'Lat': -18.3693, 'Lng': 26.5019, 'Max_Temp': 83.57, 'Humidity': 50, 'Cloudiness': 83, 'Wi ...

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list  to create a new pandas DataFrame
city_data_df= pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 0          Mataura -46.1927  168.8643     59.41        52          33
# 1            Vaini -21.2000 -175.2000     75.36        94         100
# 2        Selikhino  50.3672  137.4996      2.43        91         100
# 3     Punta Arenas -53.1500  -70.9167     46.51        71          75
# 4  Arraial Do Cabo -22.9661  -42.0278     72.30        93         100
# 5          Cascais  38.6979   -9.4215     62.51        95         100
# 6        Botevgrad  42.9000   23.7833     40.53        83          12
# 7       Valparaiso -33.0393  -71.6273     60.44        88         100
# 8             Lebu -37.6167  -73.6500     56.46        92          22
# 9           Erseke  40.3378   20.6789     38.34        92          89
#
#    Wind_Speed Country Current_Description
# 0        5.19      NZ    scattered clouds
# 1        9.22      TO       moderate rain
# 2       12.91      RU     overcast clouds
# 3        9.22      CL          light rain
# 4        2.28      BR     overcast clouds
# 5       11.99      PT     overcast clouds
# 6        5.12      BG          few clouds
# 7        9.22      CL     overcast clouds
# 8       20.29      CL          few clouds
# 9        1.59      AL     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max_Temp', 'Humidity', 'Cloudiness',
#        'Wind_Speed', 'Country', 'Current_Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max_Temp", "Humidity",  "Cloudiness", "Wind_Speed",  "Current_Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 0          Mataura      NZ -46.1927  168.8643     59.41        52          33
# 1            Vaini      TO -21.2000 -175.2000     75.36        94         100
# 2        Selikhino      RU  50.3672  137.4996      2.43        91         100
# 3     Punta Arenas      CL -53.1500  -70.9167     46.51        71          75
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     72.30        93         100
# 5          Cascais      PT  38.6979   -9.4215     62.51        95         100
# 6        Botevgrad      BG  42.9000   23.7833     40.53        83          12
# 7       Valparaiso      CL -33.0393  -71.6273     60.44        88         100
# 8             Lebu      CL -37.6167  -73.6500     56.46        92          22
# 9           Erseke      AL  40.3378   20.6789     38.34        92          89
#
#    Wind_Speed Current_Description
# 0        5.19    scattered clouds
# 1        9.22       moderate rain
# 2       12.91     overcast clouds
# 3        9.22          light rain
# 4        2.28     overcast clouds
# 5       11.99     overcast clouds
# 6        5.12          few clouds
# 7        9.22     overcast clouds
# 8       20.29          few clouds
# 9        1.59     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max_Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind_Speed             float64
# Current_Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
